# %% [markdown]
# ### RiseSet Calendar
#
# #### A unique calendar writen in Python with solarsystem package which provides:
# * Time of sun rise and set within each day
# * Time of moon rise and set within each day
# * Moon phase - percent of illumination

# %%
import solarsystem
import datetime

# %% [markdown]
# ##### Edit variables below to build a calendar for your year and area of preference
# Sun and Moon rises and sets on diffrent time at every place.
# Below we initialize our variables for Athens Greece

# %%
year=2020

# Athens Greece
longtitude = 23.72
latitude   = 37.98
# Athens is in GMT +2 time zone (setting UT = 2)
UT = 2

#########################
#Don' t edit time below
hour=12
minute=0

# %%
week = ['Mo', 'Tu', 'We', 'Th', 'Fr', 'Sa', 'Su']

# %%
# For Europe DST starts on last Sunday of March and Ends on last Sunday of October
for i in range(31,31-7,-1):
    daydate = datetime.datetime(2020, 3, i)
    strday=week[daydate.weekday()]
    if strday == 'Su':
        dst_starts = i
        break
for i in range(31,31-7,-1):
    daydate = datetime.datetime(2020, 10, i)
    strtends=week[daydate.weekday()]
    if strtends == 'Su':
        dst_ends = i
        break       
print('DST starts:', dst_starts, 'March  and DST ends: ', dst_ends, 'of October' )
# Out:
# DST starts: 29 March  and DST ends:  25 of October

# %%
# Helping dictionaries and lists
calender = [('January', range(1, 31 + 1)),
            ('Feburary', range(1, 28 + 1)),
            ('March', range(1, 31 + 1)),
            ('April', range(1, 30 + 1)),
            ('May', range(1, 31 + 1)),
            ('June', range(1, 30 + 1)),
            ('July', range(1, 31 + 1)),
            ('August', range(1, 31 + 1)),
            ('September', range(1, 30 + 1)),
            ('October', range(1, 31 + 1)),
            ('November', range(1, 30 + 1)),
            ('December', range(1, 31 + 1))]

month2num = {'January': 1,
            'Feburary': 2,
            'March': 3,
            'April': 4,
            'May': 5,
            'June': 6,
            'July': 7,
            'August': 8,
            'September': 9,
            'October': 10,
            'November': 11,
            'December':12,
           }
daysinmonth = {'January': 31,
            'Feburary': 28,
            'March': 31,
            'April': 30,
            'May': 31,
            'June': 30,
            'July': 31,
            'August': 31,
            'September': 30,
            'October': 31,
            'November': 30,
            'December':31,
           }

# %%
def is_leap(year):
    """Checks if year is a leap year"""
    if year % 4 == 0:
        if year % 100 == 0:
            if year % 400 == 0:
                return True
            else:
                return False
        else:
            return True
    else:
        return False

def make_calendar(year, start_day):
    """
    make_calendar(int, str) --> None
    """
    # Determine current starting position on calendar
    start_pos = week.index(start_day)

    # if True, adjust Feburary date range for leap year | 29 days
    if is_leap(year):
        calender[1] = ('Feburary', range(1, 29 + 1))
        daysinmonth['Feburary'] = 29
        
    for month, days in calender:

            
        # Print month title
        print('{0} {1}'.format(month, year).center(20, ' '))
        # Print Day headings
        print(''.join(['{0:<13}'.format(w) for w in week]))
        # Add spacing for non-zero starting position
        print('{0:<13}'.format('')*start_pos, end='')
        start_pos2=start_pos
        rss=''
        rss2=''
        rss2phase=''
        for day in days:
            is_dst = 0
        
            if (month2num[month]>3)&(month2num[month]<10):
                is_dst = 1
            if ((month2num[month]==3)&(day>dst_starts))|((month2num[month]==10)&(day<dst_ends)):
                is_dst = 1
            
            # Print day
            print('{0:<13}'.format(day), end='')
            sun = solarsystem.Sunriseset(year=year, month=month2num[month], day=day, 
                         UT=UT, dst=is_dst, longtitude=longtitude, latitude=latitude)

            rss = (rss + solarsystem.demical2clock(sun.riseset()[0])[:-3]+'-'+
                   solarsystem.demical2clock(sun.riseset()[1])[:-3] + '  ')
            
            moon = solarsystem.Moon(year=year, month=month2num[month], day=day, hour=hour, minute=minute, 
                         UT=UT, dst=is_dst, longtitude=longtitude, latitude=latitude, topographic=True)
            rss2 = (rss2 + solarsystem.demical2clock(moon.moonriseset()[0])[:-3]+'-'+
                   solarsystem.demical2clock(moon.moonriseset()[1])[:-3] + '  ')
            rss2phase = rss2phase + str(round(moon.phase()*100))  + '%          '
            if len(str(round(moon.phase()*100)))==1:
                rss2phase=rss2phase+' '
            if len(str(round(moon.phase()*100)))==3:
                rss2phase=rss2phase[:-1]               
            
            start_pos += 1
            if (start_pos == 7)|(day==daysinmonth[month]):
                # If start_pos == 7 (Sunday) start new line
                print()
                if (start_pos == 7):
                    start_pos = 0 # Reset counter
                if (start_pos == 0)&(day<=7):
                    rss = '{0:<13}'.format('')*start_pos2+rss
                    rss2 = '{0:<13}'.format('')*start_pos2+rss2
                    rss2phase = '{0:<13}'.format('')*start_pos2+rss2phase
                print(rss)
                print(rss2)
                print(rss2phase)
                rss=''
                rss2=''
                rss2phase=''
                print()
                

                
        print('\n')


    
daydate11 = datetime.datetime(year, 1, 1)
strtday=week[daydate11.weekday()]
make_calendar(year,strtday)
# Out:
#     January 2020
# Mo           Tu           We           Th           Fr           Sa           Su
#                           1            2            3            4            5
#                           07:41-17:15  07:41-17:16  07:41-17:17  07:41-17:18  07:41-17:19
#                           11:38-22:45  12:04-23:39  12:29-00:33  12:54-01:28  13:21-02:24
#                           32%          41%          51%          60%          69%
#
# 6            7            8            9            10           11           12
# 07:41-17:19  07:41-17:20  07:41-17:21  07:41-17:22  07:41-17:23  07:41-17:24  07:40-17:25
# 13:51-03:22  14:25-04:23  15:05-05:24  15:53-06:26  16:52-07:29  17:54-08:23  19:01-09:11
# 78%          86%          93%          97%          100%         99%          96%
#
# 13           14           15           16           17           18           19
# 07:40-17:26  07:40-17:27  07:40-17:28  07:39-17:29  07:39-17:30  07:38-17:31  07:38-17:32
# 20:11-09:54  21:20-10:31  22:28-11:04  23:34-11:35  00:40-12:06  01:44-12:37  02:47-13:11
# 90%          82%          72%          61%          50%          39%          28%
#
# 20           21           22           23           24           25           26
# 07:38-17:33  07:37-17:34  07:36-17:36  07:36-17:37  07:35-17:38  07:35-17:39  07:34-17:40
# 03:50-13:48  04:50-14:29  05:47-15:14  06:40-16:05  07:26-16:58  08:07-17:54  08:43-18:50
# 19%          12%          6%           2%           0%           0%           2%
#
# 27           28           29           30           31
# 07:33-17:41  07:33-17:42  07:32-17:43  07:31-17:44  07:30-17:46
# 09:14-19:46  09:42-20:40  10:08-21:34  10:33-22:28  10:58-23:22
# 6%           11%          17%          25%          33%
#
#
#
#    Feburary 2020
# Mo           Tu           We           Th           Fr           Sa           Su
#                                                                  1            2
#                                                                  07:29-17:47  07:29-17:48
#                                                                  11:23-00:16  11:51-01:12
#                                                                  42%          52%
#
# 3            4            5            6            7            8            9
# 07:28-17:49  07:27-17:50  07:26-17:51  07:25-17:52  07:24-17:53  07:23-17:55  07:22-17:56
# 12:23-02:10  12:59-03:10  13:42-04:11  14:33-05:10  15:32-06:07  16:38-06:58  17:52-07:48
# 62%          72%          81%          89%          95%          99%          100%
#
# 10           11           12           13           14           15           16
# 07:21-17:57  07:20-17:58  07:19-17:59  07:17-18:00  07:16-18:01  07:15-18:02  07:14-18:03
# 19:04-08:28  20:15-09:04  21:25-09:37  22:34-10:09  23:41-10:42  00:47-11:15  01:51-11:52
# 98%          93%          85%          76%          65%          54%          43%
#
# 17           18           19           20           21           22           23
# 07:13-18:04  07:12-18:06  07:10-18:07  07:09-18:08  07:08-18:09  07:06-18:10  07:05-18:11
# 02:52-12:32  03:50-13:17  04:43-14:06  05:30-14:58  06:11-15:53  06:47-16:49  07:19-17:44
# 33%          24%          16%          9%           5%           2%           0%
#
# 24           25           26           27           28           29
# 07:04-18:12  07:03-18:13  07:01-18:14  07:00-18:15  06:58-18:16  06:57-18:17
# 07:48-18:39  08:14-19:33  08:39-20:26  09:03-21:20  09:28-22:13  09:55-23:08
# 1%           3%           6%           12%          18%          26%
#
#
#
#      March 2020
# Mo           Tu           We           Th           Fr           Sa           Su
#                                                                               1
#                                                                               06:56-18:18
#                                                                               10:24-00:04
#                                                                               35%
#
# 2            3            4            5            6            7            8
# 06:54-18:19  06:53-18:20  06:51-18:21  06:50-18:22  06:48-18:23  06:47-18:24  06:46-18:25
# 10:58-01:01  11:37-02:00  12:23-02:58  13:17-03:54  14:18-04:46  15:26-05:34  16:37-06:16
# 44%          55%          65%          75%          84%          92%          97%
#
# 9            10           11           12           13           14           15
# 06:44-18:26  06:43-18:27  06:41-18:28  06:40-18:29  06:38-18:30  06:37-18:31  06:35-18:32
# 17:53-06:58  19:06-07:33  20:18-08:07  21:28-08:40  22:38-09:15  23:46-09:52  00:51-10:33
# 100%         99%          95%          88%          80%          70%          59%
#
# 16           17           18           19           20           21           22
# 06:34-18:33  06:32-18:34  06:30-18:35  06:29-18:36  06:27-18:37  06:26-18:37  06:24-18:38
# 01:51-11:18  02:46-12:07  03:35-12:59  04:18-13:54  04:54-14:50  05:27-15:45  05:55-16:40
# 49%          38%          29%          21%          14%          8%           4%
#
# 23           24           25           26           27           28           29
# 06:23-18:39  06:21-18:40  06:20-18:41  06:18-18:42  06:17-18:43  06:15-18:44  06:14-18:45
# 06:22-17:34  06:47-18:27  07:11-19:20  07:35-20:14  08:01-21:08  08:29-22:03  09:01-23:00
# 1%           0%           1%           4%           8%           13%          20%
#
# 30           31
# 07:12-19:46  07:11-19:47
# 10:35-00:54  11:18-01:51
# 28%          38%
#
#
#
#      April 2020
# Mo           Tu           We           Th           Fr           Sa           Su
#                           1            2            3            4            5
#                           07:09-19:48  07:08-19:49  07:06-19:49  07:05-19:50  07:03-19:51
#                           12:07-02:46  13:04-03:38  14:07-04:26  15:14-05:09  16:25-05:48
#                           48%          59%          70%          80%          89%
#
# 6            7            8            9            10           11           12
# 07:02-19:52  07:00-19:53  06:59-19:54  06:57-19:55  06:56-19:56  06:54-19:57  06:53-19:58
# 17:40-06:27  18:52-07:01  20:05-07:34  21:17-08:08  22:28-08:45  23:37-09:26  00:42-10:11
# 95%          99%          100%         97%          92%          84%          75%
#
# 13           14           15           16           17           18           19
# 06:51-19:59  06:50-20:00  06:49-20:01  06:47-20:01  06:46-20:02  06:44-20:03  06:43-20:04
# 01:42-11:01  02:35-11:54  03:20-12:49  03:59-13:46  04:32-14:42  05:02-15:37  05:28-16:31
# 65%          55%          45%          35%          27%          19%          12%
#
# 20           21           22           23           24           25           26
# 06:42-20:05  06:40-20:06  06:39-20:07  06:38-20:08  06:37-20:09  06:35-20:10  06:34-20:11
# 05:53-17:25  06:17-18:18  06:41-19:12  07:07-20:06  07:34-21:01  08:04-21:58  08:40-22:55
# 7%           3%           1%           0%           1%           4%           9%
#
# 27           28           29           30
# 06:33-20:12  06:32-20:13  06:30-20:14  06:29-20:14
# 09:20-23:51  10:07-00:46  11:00-01:37  12:00-02:25
# 16%          24%          33%          44%
#
#
#
#       May 2020
# Mo           Tu           We           Th           Fr           Sa           Su
#                                                     1            2            3
#                                                     06:28-20:15  06:27-20:16  06:26-20:17
#                                                     13:03-03:07  14:10-03:46  15:19-04:21
#                                                     55%          66%          77%
#
# 4            5            6            7            8            9            10
# 06:25-20:18  06:24-20:19  06:22-20:20  06:21-20:21  06:20-20:22  06:19-20:23  06:18-20:24
# 16:29-04:54  17:39-05:26  18:55-06:03  20:07-06:38  21:18-07:17  22:27-08:01  23:32-08:51
# 86%          94%          98%          100%         99%          94%          88%
#
# 11           12           13           14           15           16           17
# 06:17-20:25  06:17-20:25  06:16-20:26  06:15-20:27  06:14-20:28  06:13-20:29  06:12-20:30
# 00:30-09:45  01:20-10:42  02:02-11:40  02:38-12:38  03:09-13:35  03:36-14:30  04:01-15:24
# 80%          71%          61%          51%          42%          33%          24%
#
# 18           19           20           21           22           23           24
# 06:11-20:31  06:11-20:31  06:10-20:32  06:09-20:33  06:09-20:34  06:08-20:35  06:07-20:36
# 04:26-16:18  04:49-17:11  05:14-18:05  05:41-19:00  06:10-19:57  06:44-20:54  07:24-21:51
# 17%          11%          6%           2%           0%           0%           2%
#
# 25           26           27           28           29           30           31
# 06:07-20:36  06:06-20:37  06:06-20:38  06:05-20:39  06:05-20:39  06:04-20:40  06:04-20:41
# 08:09-22:47  09:01-23:39  09:59-00:27  11:01-01:10  12:05-01:49  13:11-02:23  14:18-02:55
# 6%           13%          20%          30%          40%          52%          63%
#
#
#
#      June 2020
# Mo           Tu           We           Th           Fr           Sa           Su
# 1            2            3            4            5            6            7
# 06:04-20:41  06:03-20:42  06:03-20:43  06:03-20:43  06:02-20:44  06:02-20:45  06:02-20:45
# 15:26-03:26  16:35-03:58  17:45-04:31  18:59-05:11  20:09-05:52  21:17-06:39  22:19-07:32
# 74%          84%          92%          97%          100%         99%          96%
#
# 8            9            10           11           12           13           14
# 06:02-20:46  06:02-20:46  06:02-20:47  06:02-20:47  06:02-20:48  06:02-20:48  06:02-20:48
# 23:14-08:30  00:00-09:29  00:39-10:30  01:13-11:28  01:42-12:25  02:08-13:21  02:32-14:15
# 91%          84%          76%          67%          58%          48%          39%
#
# 15           16           17           18           19           20           21
# 06:02-20:49  06:02-20:49  06:02-20:50  06:02-20:50  06:02-20:50  06:02-20:50  06:02-20:51
# 02:56-15:09  03:21-16:03  03:47-16:57  04:15-17:53  04:48-18:51  05:26-19:48  06:10-20:45
# 30%          22%          15%          9%           4%           1%           0%
#
# 22           23           24           25           26           27           28
# 06:03-20:51  06:03-20:51  06:03-20:51  06:04-20:51  06:04-20:51  06:04-20:51  06:05-20:51
# 07:01-21:39  07:58-22:29  09:00-23:14  10:04-23:53  11:10-00:28  12:15-01:00  13:21-01:31
# 1%           5%           10%          18%          27%          38%          50%
#
# 29           30
# 06:05-20:51  06:06-20:51
# 14:28-02:01  15:35-02:32
# 61%          72%
#
#
#
#      July 2020
# Mo           Tu           We           Th           Fr           Sa           Su
#                           1            2            3            4            5
#                           06:06-20:51  06:07-20:51  06:07-20:51  06:08-20:51  06:08-20:50
#                           16:43-03:06  17:52-03:44  18:59-04:28  20:07-05:22  21:05-06:18
#                           82%          90%          96%          99%          100%
#
# 6            7            8            9            10           11           12
# 06:09-20:50  06:09-20:50  06:10-20:50  06:10-20:49  06:11-20:49  06:12-20:49  06:12-20:48
# 21:55-07:17  22:37-08:18  23:13-09:19  23:45-10:18  00:12-11:15  00:37-12:10  01:02-13:04
# 98%          94%          88%          81%          73%          64%          55%
#
# 13           14           15           16           17           18           19
# 06:13-20:48  06:14-20:47  06:15-20:47  06:15-20:46  06:16-20:46  06:17-20:45  06:18-20:44
# 01:26-13:59  01:51-14:53  02:19-15:49  02:50-16:45  03:26-17:43  04:09-18:40  04:58-19:35
# 46%          36%          27%          19%          12%          6%           2%
#
# 20           21           22           23           24           25           26
# 06:18-20:44  06:19-20:43  06:20-20:42  06:21-20:42  06:21-20:41  06:22-20:40  06:23-20:39
# 05:53-20:27  06:55-21:14  07:59-21:55  09:06-22:32  10:13-23:05  11:19-23:36  12:25-00:06
# 0%           0%           3%           9%           16%          25%          36%
#
# 27           28           29           30           31
# 06:24-20:38  06:25-20:38  06:26-20:37  06:26-20:36  06:27-20:35
# 13:32-00:36  14:39-01:09  15:46-01:45  16:52-02:26  17:55-03:13
# 47%          59%          70%          80%          88%
#
#
#
#     August 2020
# Mo           Tu           We           Th           Fr           Sa           Su
#                                                                  1            2
#                                                                  06:28-20:34  06:29-20:33
#                                                                  18:54-04:06  19:50-05:08
#                                                                  94%          98%
#
# 3            4            5            6            7            8            9
# 06:30-20:32  06:31-20:31  06:32-20:30  06:32-20:29  06:33-20:27  06:34-20:26  06:35-20:25
# 20:35-06:08  21:13-07:09  21:46-08:09  22:15-09:08  22:41-10:04  23:06-10:59  23:30-11:54
# 100%         99%          97%          92%          86%          79%          71%
#
# 10           11           12           13           14           15           16
# 06:36-20:24  06:37-20:23  06:38-20:22  06:38-20:20  06:39-20:19  06:40-20:18  06:41-20:17
# 23:55-12:48  00:22-13:44  00:52-14:40  01:26-15:36  02:05-16:33  02:52-17:29  03:45-18:22
# 62%          52%          43%          33%          24%          16%          9%
#
# 17           18           19           20           21           22           23
# 06:42-20:15  06:43-20:14  06:44-20:13  06:45-20:11  06:45-20:10  06:46-20:09  06:47-20:07
# 04:45-19:10  05:49-19:54  06:56-20:32  08:04-21:07  09:12-21:39  10:20-22:10  11:28-22:41
# 4%           1%           0%           2%           7%           14%          23%
#
# 24           25           26           27           28           29           30
# 06:48-20:06  06:49-20:04  06:50-20:03  06:51-20:02  06:51-20:00  06:52-19:59  06:53-19:57
# 12:35-23:13  13:43-23:48  14:49-00:28  15:53-01:13  16:52-02:03  17:45-02:59  18:31-03:58
# 34%          45%          56%          67%          76%          85%          91%
#
# 31
# 06:54-19:56
# 19:14-05:02
# 96%
#
#
#
#    September 2020
# Mo           Tu           We           Th           Fr           Sa           Su
#              1            2            3            4            5            6
#              06:55-19:54  06:56-19:53  06:57-19:51  06:57-19:50  06:58-19:48  06:59-19:47
#              19:48-06:02  20:17-07:01  20:44-07:59  21:09-08:55  21:34-09:50  21:58-10:45
#              99%          100%         98%          95%          90%          84%
#
# 7            8            9            10           11           12           13
# 07:00-19:45  07:01-19:44  07:02-19:42  07:03-19:40  07:03-19:39  07:04-19:37  07:05-19:36
# 22:24-11:40  22:53-12:36  23:25-13:32  00:03-14:28  00:46-15:24  01:36-16:17  02:33-17:06
# 77%          68%          59%          49%          39%          29%          20%
#
# 14           15           16           17           18           19           20
# 07:06-19:34  07:07-19:33  07:08-19:31  07:08-19:29  07:09-19:28  07:10-19:26  07:11-19:25
# 03:35-17:51  04:41-18:31  05:49-19:07  06:58-19:40  08:07-20:11  09:16-20:42  10:26-21:15
# 12%          6%           2%           0%           1%           5%           12%
#
# 21           22           23           24           25           26           27
# 07:12-19:23  07:13-19:22  07:14-19:20  07:15-19:19  07:15-19:17  07:16-19:15  07:17-19:14
# 11:36-21:50  12:44-22:29  13:50-23:13  14:51-00:03  15:46-00:57  16:33-01:55  17:13-02:55
# 20%          30%          41%          52%          62%          72%          81%
#
# 28           29           30
# 07:18-19:12  07:19-19:11  07:20-19:09
# 17:48-03:55  18:18-04:53  18:49-05:55
# 88%          94%          98%
#
#
#
#     October 2020
# Mo           Tu           We           Th           Fr           Sa           Su
#                                        1            2            3            4
#                                        07:21-19:08  07:22-19:06  07:22-19:05  07:23-19:03
#                                        19:14-06:51  19:38-07:47  20:03-08:42  20:28-09:37
#                                        99%          99%          98%          94%
#
# 5            6            7            8            9            10           11
# 07:24-19:02  07:25-19:00  07:26-18:59  07:27-18:57  07:28-18:56  07:29-18:54  07:30-18:53
# 20:56-10:33  21:27-11:30  22:02-12:26  22:43-13:22  23:31-14:15  00:24-15:05  01:24-15:50
# 89%          82%          74%          65%          55%          45%          35%
#
# 12           13           14           15           16           17           18
# 07:31-18:51  07:32-18:50  07:33-18:48  07:34-18:47  07:35-18:46  07:36-18:44  07:37-18:43
# 02:27-16:30  03:33-17:06  04:41-17:40  05:49-18:11  06:59-18:42  08:09-19:14  09:20-19:48
# 25%          16%          8%           3%           0%           0%           3%
#
# 19           20           21           22           23           24           25
# 07:38-18:42  07:38-18:40  07:39-18:39  07:40-18:38  07:41-18:36  07:42-18:35  06:44-17:34
# 10:31-20:26  11:41-21:10  12:45-21:59  13:43-22:53  14:34-23:52  15:16-00:52  14:53-00:54
# 9%           17%          26%          36%          47%          57%          67%
#
# 26           27           28           29           30           31
# 06:45-17:33  06:46-17:31  06:47-17:30  06:48-17:29  06:49-17:28  06:50-17:27
# 15:23-01:52  15:51-02:50  16:16-03:46  16:40-04:41  17:04-05:37  17:33-06:36
# 76%          84%          90%          95%          98%          100%
#
#
#
#    November 2020
# Mo           Tu           We           Th           Fr           Sa           Su
#                                                                               1
#                                                                               06:51-17:26
#                                                                               18:00-07:33
#                                                                               99%
#
# 2            3            4            5            6            7            8
# 06:52-17:25  06:53-17:23  06:54-17:22  06:55-17:21  06:56-17:20  06:57-17:19  06:58-17:19
# 18:30-08:30  19:05-09:28  19:45-10:24  20:31-11:18  21:23-12:09  22:20-12:54  23:22-13:35
# 97%          93%          87%          79%          71%          61%          50%
#
# 9            10           11           12           13           14           15
# 06:59-17:18  07:00-17:17  07:01-17:16  07:03-17:15  07:04-17:14  07:05-17:14  07:06-17:13
# 00:26-14:11  01:31-14:44  02:38-15:15  03:46-15:45  04:55-16:15  06:05-16:48  07:16-17:25
# 39%          29%          19%          11%          5%           1%           0%
#
# 16           17           18           19           20           21           22
# 07:07-17:12  07:08-17:11  07:09-17:11  07:10-17:10  07:11-17:10  07:12-17:09  07:13-17:09
# 08:27-18:06  09:35-18:54  10:37-19:48  11:31-20:47  12:17-21:48  12:55-22:49  13:27-23:48
# 2%           7%           13%          21%          31%          41%          51%
#
# 23           24           25           26           27           28           29
# 07:14-17:08  07:15-17:08  07:16-17:07  07:17-17:07  07:18-17:06  07:19-17:06  07:20-17:06
# 13:56-00:46  14:21-01:43  14:45-02:38  15:09-03:33  15:34-04:28  16:00-05:25  16:29-06:22
# 60%          70%          78%          85%          92%          96%          99%
#
# 30
# 07:21-17:06
# 17:06-07:24
# 100%
#
#
#
#    December 2020
# Mo           Tu           We           Th           Fr           Sa           Su
#              1            2            3            4            5            6
#              07:22-17:05  07:23-17:05  07:24-17:05  07:25-17:05  07:26-17:05  07:27-17:05
#              17:45-08:22  18:30-09:18  19:21-10:10  20:18-10:58  21:19-11:39  22:22-12:16
#              99%          96%          91%          84%          76%          66%
#
# 7            8            9            10           11           12           13
# 07:28-17:05  07:28-17:05  07:29-17:05  07:30-17:05  07:31-17:05  07:32-17:05  07:32-17:06
# 23:26-12:49  00:30-13:19  01:36-13:48  02:42-14:17  03:50-14:48  04:59-15:22  06:09-16:00
# 55%          44%          33%          23%          14%          7%           2%
#
# 14           15           16           17           18           19           20
# 07:33-17:06  07:34-17:06  07:34-17:07  07:35-17:07  07:36-17:07  07:36-17:08  07:37-17:08
# 07:18-16:45  08:23-17:37  09:21-18:35  10:11-19:36  10:53-20:38  11:29-21:40  11:59-22:40
# 0%           1%           4%           9%           16%          24%          33%
#
# 21           22           23           24           25           26           27
# 07:37-17:09  07:38-17:09  07:38-17:10  07:38-17:10  07:39-17:11  07:39-17:11  07:40-17:12
# 12:25-23:37  12:50-00:33  13:14-01:28  13:38-02:23  14:03-03:19  14:31-04:16  15:03-05:13
# 43%          53%          62%          71%          79%          87%          93%
#
# 28           29           30           31
# 07:40-17:13  07:40-17:14  07:40-17:14  07:41-17:15
# 15:40-06:12  16:23-07:09  17:17-08:08  18:14-08:57
# 97%          99%          100%         98%
