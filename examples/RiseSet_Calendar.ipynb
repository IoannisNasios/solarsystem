# %% [markdown]
# ### RiseSet Calendar
#
# #### A unique calendar writen in Python with solarsystem package which provides:
# * Time of sun rise and set within each day
# * Time of moon rise and set within each day
# * Moon phase - percent of illumination

# %%
import solarsystem
import datetime

# %%
print(solarsystem.__version__)
# Out:
# 0.1.6

# %% [markdown]
# ##### Edit variables below to build a calendar for your year and area of preference
# Sun and Moon rises and sets on diffrent time at every place.
# Below we initialize our variables for Athens Greece

# %%
year=2026

# Athens Greece
longtitude = 23.72
latitude   = 37.98
# Athens is in GMT +2 time zone (setting UT = 2)
UT = 2

#########################
#Don' t edit time below
hour=12
minute=0

# %%
week = ['Mo', 'Tu', 'We', 'Th', 'Fr', 'Sa', 'Su']

# %%
# For Europe DST starts on last Sunday of March and Ends on last Sunday of October
for i in range(31,31-7,-1):
    daydate = datetime.datetime(2020, 3, i)
    strday=week[daydate.weekday()]
    if strday == 'Su':
        dst_starts = i
        break
for i in range(31,31-7,-1):
    daydate = datetime.datetime(2020, 10, i)
    strtends=week[daydate.weekday()]
    if strtends == 'Su':
        dst_ends = i
        break       
print('DST starts:', dst_starts, 'March  and DST ends: ', dst_ends, 'of October' )
# Out:
# DST starts: 29 March  and DST ends:  25 of October

# %%
# Helping dictionaries and lists
calender = [('January', range(1, 31 + 1)),
            ('Feburary', range(1, 28 + 1)),
            ('March', range(1, 31 + 1)),
            ('April', range(1, 30 + 1)),
            ('May', range(1, 31 + 1)),
            ('June', range(1, 30 + 1)),
            ('July', range(1, 31 + 1)),
            ('August', range(1, 31 + 1)),
            ('September', range(1, 30 + 1)),
            ('October', range(1, 31 + 1)),
            ('November', range(1, 30 + 1)),
            ('December', range(1, 31 + 1))]

month2num = {'January': 1,
            'Feburary': 2,
            'March': 3,
            'April': 4,
            'May': 5,
            'June': 6,
            'July': 7,
            'August': 8,
            'September': 9,
            'October': 10,
            'November': 11,
            'December':12,
           }
daysinmonth = {'January': 31,
            'Feburary': 28,
            'March': 31,
            'April': 30,
            'May': 31,
            'June': 30,
            'July': 31,
            'August': 31,
            'September': 30,
            'October': 31,
            'November': 30,
            'December':31,
           }

# %%
def is_leap(year):
    """Checks if year is a leap year"""
    if year % 4 == 0:
        if year % 100 == 0:
            if year % 400 == 0:
                return True
            else:
                return False
        else:
            return True
    else:
        return False

def make_calendar(year, start_day):
    """
    make_calendar(int, str) --> None
    """
    # Determine current starting position on calendar
    start_pos = week.index(start_day)

    # if True, adjust Feburary date range for leap year | 29 days
    if is_leap(year):
        calender[1] = ('Feburary', range(1, 29 + 1))
        daysinmonth['Feburary'] = 29
        
    for month, days in calender:

            
        # Print month title
        print('{0} {1}'.format(month, year).center(20, ' '))
        # Print Day headings
        print(''.join(['{0:<13}'.format(w) for w in week]))
        # Add spacing for non-zero starting position
        print('{0:<13}'.format('')*start_pos, end='')
        start_pos2=start_pos
        rss=''
        rss2=''
        rss2phase=''
        for day in days:
            is_dst = 0
        
            if (month2num[month]>3)&(month2num[month]<10):
                is_dst = 1
            if ((month2num[month]==3)&(day>dst_starts))|((month2num[month]==10)&(day<dst_ends)):
                is_dst = 1
            
            # Print day
            print('{0:<13}'.format(day), end='')
            sun = solarsystem.Sunriseset(year=year, month=month2num[month], day=day, 
                         UT=UT, dst=is_dst, longtitude=longtitude, latitude=latitude)

            rss = (rss + solarsystem.demical2clock(sun.riseset()[0])[:-3]+'-'+
                   solarsystem.demical2clock(sun.riseset()[1])[:-3] + '  ')
            
            moon = solarsystem.Moon(year=year, month=month2num[month], day=day, hour=hour, minute=minute, 
                         UT=UT, dst=is_dst, longtitude=longtitude, latitude=latitude, topographic=True)
            rss2 = (rss2 + solarsystem.demical2clock(moon.moonriseset()[0])[:-3]+'-'+
                   solarsystem.demical2clock(moon.moonriseset()[1])[:-3] + '  ')
            rss2phase = rss2phase + str(round(moon.phase()*100))  + '%          '
            if len(str(round(moon.phase()*100)))==1:
                rss2phase=rss2phase+' '
            if len(str(round(moon.phase()*100)))==3:
                rss2phase=rss2phase[:-1]               
            
            start_pos += 1
            if (start_pos == 7)|(day==daysinmonth[month]):
                # If start_pos == 7 (Sunday) start new line
                print()
                if (start_pos == 7):
                    start_pos = 0 # Reset counter
                if (start_pos == 0)&(day<=7):
                    rss = '{0:<13}'.format('')*start_pos2+rss
                    rss2 = '{0:<13}'.format('')*start_pos2+rss2
                    rss2phase = '{0:<13}'.format('')*start_pos2+rss2phase
                print(rss)
                print(rss2)
                print(rss2phase)
                rss=''
                rss2=''
                rss2phase=''
                print()
                

                
        print('\n')


    
daydate11 = datetime.datetime(year, 1, 1)
strtday=week[daydate11.weekday()]
make_calendar(year,strtday)
# Out:
#     January 2026
# Mo           Tu           We           Th           Fr           Sa           Su
#                                        1            2            3            4
#                                        07:41-17:16  07:41-17:16  07:41-17:17  07:41-17:18
#                                        14:42-05:54  15:43-07:03  16:57-08:06  18:11-08:54
#                                        94%          98%          100%         98%
#
# 5            6            7            8            9            10           11
# 07:41-17:19  07:41-17:20  07:41-17:21  07:41-17:22  07:41-17:23  07:41-17:24  07:40-17:25
# 19:24-09:32  20:33-10:02  21:39-10:28  22:41-10:51  23:41-11:13  00:39-11:35  01:36-11:59
# 94%          88%          79%          70%          61%          51%          41%
#
# 12           13           14           15           16           17           18
# 07:40-17:26  07:40-17:27  07:40-17:28  07:39-17:29  07:39-17:30  07:39-17:31  07:38-17:32
# 02:34-12:25  03:32-12:54  04:29-13:29  05:24-14:10  06:15-14:58  07:01-15:52  07:40-16:51
# 32%          24%          17%          10%          6%           2%           0%
#
# 19           20           21           22           23           24           25
# 07:38-17:33  07:37-17:34  07:37-17:35  07:36-17:36  07:36-17:37  07:35-17:38  07:34-17:39
# 08:14-17:52  08:44-18:54  09:10-19:56  09:34-20:57  09:57-21:59  10:20-23:03  10:46-00:08
# 0%           2%           6%           12%          20%          29%          40%
#
# 26           27           28           29           30           31
# 07:34-17:41  07:33-17:42  07:32-17:43  07:31-17:44  07:31-17:45  07:30-17:46
# 11:15-01:17  11:51-02:28  12:35-03:40  13:29-04:49  14:34-05:50  15:45-06:41
# 51%          62%          73%          83%          91%          97%
#
#
#
#    Feburary 2026
# Mo           Tu           We           Th           Fr           Sa           Su
#                                                                               1
#                                                                               07:29-17:47
#                                                                               17:02-07:26
#                                                                               100%
#
# 2            3            4            5            6            7            8
# 07:28-17:48  07:27-17:50  07:26-17:51  07:25-17:52  07:24-17:53  07:23-17:54  07:22-17:55
# 18:14-08:00  19:22-08:28  20:27-08:53  21:29-09:16  22:30-09:38  23:29-10:02  00:28-10:27
# 100%         97%          92%          85%          77%          68%          59%
#
# 9            10           11           12           13           14           15
# 07:21-17:56  07:20-17:57  07:19-17:59  07:18-18:00  07:17-18:01  07:16-18:02  07:15-18:03
# 01:27-10:56  02:25-11:29  03:22-12:09  04:14-12:55  05:01-13:47  05:43-14:45  06:18-15:46
# 50%          40%          31%          23%          16%          10%          5%
#
# 16           17           18           19           20           21           22
# 07:13-18:04  07:12-18:05  07:11-18:06  07:10-18:07  07:08-18:08  07:07-18:09  07:06-18:10
# 06:49-16:48  07:16-17:51  07:41-18:54  08:04-19:57  08:28-21:01  08:53-22:06  09:22-23:14
# 1%           0%           1%           4%           9%           16%          25%
#
# 23           24           25           26           27           28
# 07:04-18:11  07:03-18:12  07:02-18:14  07:00-18:15  06:59-18:16  06:58-18:17
# 09:55-00:24  10:36-01:35  11:26-02:43  12:26-03:44  13:33-04:36  14:44-05:20
# 36%          47%          59%          70%          80%          89%
#
#
#
#      March 2026
# Mo           Tu           We           Th           Fr           Sa           Su
#                                                                               1
#                                                                               06:56-18:18
#                                                                               15:55-05:55
#                                                                               95%
#
# 2            3            4            5            6            7            8
# 06:55-18:19  06:53-18:20  06:52-18:21  06:51-18:22  06:49-18:23  06:48-18:24  06:46-18:25
# 17:03-06:24  18:13-06:54  19:16-07:18  20:18-07:40  21:18-08:04  22:19-08:29  23:19-08:56
# 99%          100%         99%          95%          90%          84%          76%
#
# 9            10           11           12           13           14           15
# 06:45-18:26  06:43-18:27  06:42-18:28  06:40-18:28  06:39-18:29  06:37-18:30  06:36-18:31
# 00:19-09:29  01:16-10:06  02:11-10:51  03:00-11:41  03:43-12:37  04:20-13:37  04:52-14:39
# 67%          58%          49%          39%          30%          22%          14%
#
# 16           17           18           19           20           21           22
# 06:34-18:32  06:33-18:33  06:31-18:34  06:30-18:35  06:28-18:36  06:27-18:37  06:25-18:38
# 05:20-15:41  05:46-16:44  06:10-17:48  06:34-18:52  06:59-19:59  07:27-21:08  08:00-22:19
# 8%           3%           1%           0%           2%           7%           14%
#
# 23           24           25           26           27           28           29
# 06:24-18:39  06:22-18:40  06:20-18:41  06:19-18:42  06:17-18:43  06:16-18:44  06:14-18:44
# 08:40-23:30  09:28-00:40  10:26-01:43  11:30-02:36  12:39-03:21  13:48-03:57  14:55-04:27
# 23%          33%          44%          56%          67%          77%          86%
#
# 30           31
# 07:13-19:45  07:11-19:46
# 16:58-05:53  18:05-06:21
# 92%          97%
#
#
#
#      April 2026
# Mo           Tu           We           Th           Fr           Sa           Su
#                           1            2            3            4            5
#                           07:10-19:47  07:08-19:48  07:07-19:49  07:05-19:50  07:04-19:51
#                           19:06-06:44  20:07-07:06  21:08-07:31  22:08-07:58  23:08-08:28
#                           99%          100%         98%          94%          89%
#
# 6            7            8            9            10           11           12
# 07:02-19:52  07:01-19:53  06:59-19:54  06:58-19:55  06:56-19:55  06:55-19:56  06:54-19:57
# 00:07-09:04  01:03-09:46  01:54-10:34  02:40-11:28  03:18-12:26  03:52-13:26  04:21-14:27
# 82%          74%          66%          57%          47%          38%          29%
#
# 13           14           15           16           17           18           19
# 06:52-19:58  06:51-19:59  06:49-20:00  06:48-20:01  06:46-20:02  06:45-20:03  06:44-20:04
# 04:47-15:29  05:11-16:32  05:35-17:36  06:00-18:41  06:28-19:50  06:59-21:02  07:37-22:15
# 20%          12%          6%           2%           0%           1%           5%
#
# 20           21           22           23           24           25           26
# 06:42-20:05  06:41-20:06  06:40-20:07  06:38-20:08  06:37-20:08  06:36-20:09  06:35-20:10
# 08:24-23:28  09:20-00:35  10:24-01:33  11:33-02:21  12:43-02:59  13:50-03:31  14:55-03:58
# 11%          19%          30%          41%          52%          63%          73%
#
# 27           28           29           30
# 06:33-20:11  06:32-20:12  06:31-20:13  06:30-20:14
# 15:57-04:22  16:58-04:44  17:58-05:07  19:01-05:35
# 82%          89%          95%          98%
#
#
#
#       May 2026
# Mo           Tu           We           Th           Fr           Sa           Su
#                                                     1            2            3
#                                                     06:29-20:15  06:27-20:16  06:26-20:17
#                                                     20:02-06:01  21:02-06:30  22:02-07:05
#                                                     100%         99%          97%
#
# 4            5            6            7            8            9            10
# 06:25-20:18  06:24-20:19  06:23-20:20  06:22-20:21  06:21-20:21  06:20-20:22  06:19-20:23
# 22:59-07:45  23:52-08:32  00:39-09:24  01:20-10:21  01:55-11:20  02:25-12:20  02:51-13:21
# 93%          87%          80%          72%          64%          54%          44%
#
# 11           12           13           14           15           16           17
# 06:18-20:24  06:17-20:25  06:16-20:26  06:15-20:27  06:14-20:28  06:13-20:29  06:13-20:29
# 03:15-14:22  03:39-15:24  04:03-16:27  04:29-17:34  04:59-18:44  05:34-19:57  06:18-21:11
# 34%          25%          16%          9%           3%           0%           0%
#
# 18           19           20           21           22           23           24
# 06:12-20:30  06:11-20:31  06:10-20:32  06:10-20:33  06:09-20:34  06:08-20:34  06:08-20:35
# 07:12-22:22  08:15-23:25  09:25-00:17  10:36-00:59  11:45-01:34  12:52-02:02  13:55-02:27
# 3%           9%           17%          27%          37%          48%          59%
#
# 25           26           27           28           29           30           31
# 06:07-20:36  06:07-20:37  06:06-20:38  06:06-20:38  06:05-20:39  06:05-20:40  06:04-20:40
# 14:56-02:50  15:55-03:12  16:54-03:36  17:54-04:01  18:54-04:29  19:58-05:06  20:56-05:45
# 69%          78%          86%          92%          96%          99%          100%
#
#
#
#      June 2026
# Mo           Tu           We           Th           Fr           Sa           Su
# 1            2            3            4            5            6            7
# 06:04-20:41  06:03-20:42  06:03-20:42  06:03-20:43  06:03-20:44  06:02-20:44  06:02-20:45
# 21:51-06:30  22:40-07:22  23:22-08:18  23:58-09:17  00:29-10:17  00:56-11:17  01:21-12:17
# 99%          96%          91%          85%          78%          69%          60%
#
# 8            9            10           11           12           13           14
# 06:02-20:45  06:02-20:46  06:02-20:46  06:02-20:47  06:02-20:47  06:02-20:48  06:02-20:48
# 01:44-13:17  02:07-14:18  02:32-15:22  02:59-16:29  03:32-17:40  04:12-18:52  05:01-20:04
# 50%          39%          29%          19%          11%          5%           1%
#
# 15           16           17           18           19           20           21
# 06:02-20:49  06:02-20:49  06:02-20:49  06:02-20:50  06:02-20:50  06:02-20:50  06:02-20:50
# 06:01-21:11  07:10-22:08  08:22-22:55  09:34-23:33  10:43-00:04  11:49-00:30  12:51-00:54
# 0%           2%           7%           14%          23%          33%          44%
#
# 22           23           24           25           26           27           28
# 06:03-20:51  06:03-20:51  06:03-20:51  06:03-20:51  06:04-20:51  06:04-20:51  06:05-20:51
# 13:52-01:17  14:52-01:40  15:51-02:05  16:51-02:32  17:51-03:04  18:49-03:41  19:49-04:29
# 54%          64%          73%          81%          88%          94%          97%
#
# 29           30
# 06:05-20:51  06:05-20:51
# 20:39-05:19  21:24-06:15
# 99%          100%
#
#
#
#      July 2026
# Mo           Tu           We           Th           Fr           Sa           Su
#                           1            2            3            4            5
#                           06:06-20:51  06:06-20:51  06:07-20:51  06:07-20:51  06:08-20:51
#                           22:02-07:14  22:34-08:15  23:02-09:15  23:27-10:15  23:50-11:15
#                           98%          94%          89%          82%          74%
#
# 6            7            8            9            10           11           12
# 06:08-20:50  06:09-20:50  06:10-20:50  06:10-20:50  06:11-20:49  06:11-20:49  06:12-20:48
# 00:13-12:15  00:36-13:17  01:02-14:21  01:32-15:29  02:08-16:39  02:53-17:50  03:49-18:58
# 64%          54%          43%          32%          22%          13%          6%
#
# 13           14           15           16           17           18           19
# 06:13-20:48  06:14-20:48  06:14-20:47  06:15-20:46  06:16-20:46  06:16-20:45  06:17-20:45
# 04:53-19:58  06:05-20:49  07:18-21:30  08:29-22:04  09:37-22:33  10:42-22:58  11:44-23:21
# 2%           0%           1%           5%           11%          19%          29%
#
# 20           21           22           23           24           25           26
# 06:18-20:44  06:19-20:43  06:20-20:43  06:20-20:42  06:21-20:41  06:22-20:40  06:23-20:40
# 12:45-23:44  13:46-00:09  14:46-00:35  15:46-01:06  16:45-01:42  17:42-02:23  18:34-03:12
# 38%          48%          58%          68%          76%          84%          90%
#
# 27           28           29           30           31
# 06:24-20:39  06:24-20:38  06:25-20:37  06:26-20:36  06:27-20:35
# 19:20-04:06  20:04-05:09  20:38-06:10  21:07-07:11  21:33-08:13
# 95%          98%          100%         99%          97%
#
#
#
#     August 2026
# Mo           Tu           We           Th           Fr           Sa           Su
#                                                                  1            2
#                                                                  06:28-20:34  06:29-20:33
#                                                                  21:57-09:13  22:20-10:14
#                                                                  92%          86%
#
# 3            4            5            6            7            8            9
# 06:29-20:32  06:30-20:31  06:31-20:30  06:32-20:29  06:33-20:28  06:34-20:27  06:35-20:26
# 22:43-11:16  23:08-12:19  23:36-13:25  00:10-14:33  00:51-15:43  01:41-16:50  02:42-17:52
# 78%          68%          57%          46%          35%          24%          15%
#
# 10           11           12           13           14           15           16
# 06:35-20:25  06:36-20:23  06:37-20:22  06:38-20:21  06:39-20:20  06:40-20:18  06:41-20:17
# 03:50-18:45  05:02-19:28  06:13-20:04  07:23-20:34  08:29-21:01  09:33-21:25  10:35-21:48
# 8%           3%           0%           1%           3%           9%           15%
#
# 17           18           19           20           21           22           23
# 06:42-20:16  06:42-20:15  06:43-20:13  06:44-20:12  06:45-20:11  06:46-20:09  06:47-20:08
# 11:37-22:12  12:38-22:39  13:39-23:08  14:38-23:42  15:36-00:22  16:30-01:08  17:18-02:00
# 23%          32%          42%          52%          61%          70%          78%
#
# 24           25           26           27           28           29           30
# 06:48-20:06  06:48-20:05  06:49-20:04  06:50-20:02  06:51-20:01  06:52-19:59  06:53-19:58
# 17:59-02:58  18:35-03:58  19:10-05:04  19:37-06:06  20:02-07:08  20:25-08:10  20:49-09:13
# 86%          92%          97%          99%          100%         98%          95%
#
# 31
# 06:54-19:56
# 21:14-10:17
# 88%
#
#
#
#    September 2026
# Mo           Tu           We           Th           Fr           Sa           Su
#              1            2            3            4            5            6
#              06:54-19:55  06:55-19:53  06:56-19:52  06:57-19:50  06:58-19:49  06:59-19:47
#              21:42-11:23  22:14-12:32  22:53-13:41  23:41-14:48  00:38-15:50  01:42-16:44
#              80%          71%          60%          48%          37%          26%
#
# 7            8            9            10           11           12           13
# 07:00-19:46  07:00-19:44  07:01-19:43  07:02-19:41  07:03-19:40  07:04-19:38  07:05-19:36
# 02:52-17:29  04:02-18:06  05:11-18:37  06:17-19:05  07:22-19:29  08:24-19:53  09:26-20:17
# 17%          9%           4%           1%           0%           2%           6%
#
# 14           15           16           17           18           19           20
# 07:06-19:35  07:06-19:33  07:07-19:32  07:08-19:30  07:09-19:29  07:10-19:27  07:11-19:26
# 10:28-20:42  11:29-21:11  12:29-21:43  13:28-22:21  14:23-23:05  15:13-23:55  15:56-00:50
# 11%          18%          26%          35%          44%          54%          63%
#
# 21           22           23           24           25           26           27
# 07:12-19:24  07:12-19:22  07:13-19:21  07:14-19:19  07:15-19:18  07:16-19:16  07:17-19:15
# 16:34-01:49  17:06-02:50  17:35-03:51  18:00-04:53  18:28-06:00  18:52-07:03  19:17-08:08
# 72%          80%          88%          94%          98%          100%         99%
#
# 28           29           30
# 07:18-19:13  07:18-19:11  07:19-19:10
# 19:45-09:16  20:17-10:26  20:56-11:37
# 96%          91%          83%
#
#
#
#     October 2026
# Mo           Tu           We           Th           Fr           Sa           Su
#                                        1            2            3            4
#                                        07:20-19:08  07:21-19:07  07:22-19:05  07:23-19:04
#                                        21:42-12:47  22:38-13:51  23:41-14:47  00:49-15:33
#                                        73%          62%          51%          39%
#
# 5            6            7            8            9            10           11
# 07:24-19:02  07:25-19:01  07:26-18:59  07:27-18:58  07:28-18:56  07:28-18:55  07:29-18:53
# 01:58-16:12  03:06-16:43  04:11-17:10  05:15-17:35  06:17-17:59  07:18-18:22  08:19-18:47
# 29%          19%          12%          6%           2%           0%           1%
#
# 12           13           14           15           16           17           18
# 07:30-18:52  07:31-18:50  07:32-18:49  07:33-18:48  07:34-18:46  07:35-18:45  07:36-18:44
# 09:20-19:15  10:21-19:46  11:20-20:22  12:16-21:03  13:07-21:51  13:52-22:44  14:32-23:41
# 3%           7%           13%          20%          28%          37%          46%
#
# 19           20           21           22           23           24           25
# 07:37-18:42  07:38-18:41  07:39-18:39  07:40-18:38  07:41-18:37  07:42-18:36  06:43-17:34
# 15:05-00:40  15:34-01:40  16:01-02:41  16:25-03:42  16:49-04:44  17:14-05:49  16:41-05:58
# 55%          65%          74%          83%          90%          96%          99%
#
# 26           27           28           29           30           31
# 06:44-17:33  06:45-17:32  06:46-17:31  06:47-17:29  06:48-17:28  06:49-17:27
# 17:16-07:13  17:53-08:27  18:39-09:40  19:35-10:49  20:39-11:49  21:49-12:39
# 100%         98%          93%          85%          76%          65%
#
#
#
#    November 2026
# Mo           Tu           We           Th           Fr           Sa           Su
#                                                                               1
#                                                                               06:50-17:26
#                                                                               23:00-13:19
#                                                                               53%
#
# 2            3            4            5            6            7            8
# 06:51-17:25  06:52-17:24  06:53-17:23  06:55-17:22  06:56-17:21  06:57-17:20  06:58-17:19
# 00:08-13:52  01:14-14:20  02:17-14:45  03:19-15:08  04:19-15:32  05:19-15:56  06:19-16:23
# 42%          32%          22%          14%          8%           3%           1%
#
# 9            10           11           12           13           14           15
# 06:59-17:18  07:00-17:17  07:01-17:16  07:02-17:15  07:03-17:15  07:04-17:14  07:05-17:13
# 07:19-16:53  08:18-17:28  09:15-18:08  10:06-18:54  10:52-19:45  11:32-20:40  12:06-21:37
# 0%           1%           4%           9%           14%          21%          29%
#
# 16           17           18           19           20           21           22
# 07:06-17:12  07:07-17:12  07:08-17:11  07:10-17:10  07:11-17:10  07:12-17:09  07:13-17:09
# 12:36-22:35  13:02-23:34  13:27-00:33  13:50-01:33  14:13-02:35  14:39-03:39  15:08-04:48
# 38%          48%          58%          67%          77%          86%          93%
#
# 23           24           25           26           27           28           29
# 07:14-17:08  07:15-17:08  07:16-17:07  07:17-17:07  07:18-17:07  07:19-17:06  07:20-17:06
# 15:42-06:01  16:25-07:16  17:22-08:33  18:26-09:39  19:37-10:35  20:51-11:20  22:03-11:56
# 98%          100%         99%          95%          88%          79%          69%
#
# 30
# 07:21-17:06
# 23:12-12:26
# 58%
#
#
#
#    December 2026
# Mo           Tu           We           Th           Fr           Sa           Su
#              1            2            3            4            5            6
#              07:22-17:05  07:23-17:05  07:24-17:05  07:25-17:05  07:25-17:05  07:26-17:05
#              00:17-12:52  01:19-13:16  02:20-13:39  03:20-14:03  04:19-14:29  05:19-14:59
#              47%          36%          27%          18%          11%          6%
#
# 7            8            9            10           11           12           13
# 07:27-17:05  07:28-17:05  07:29-17:05  07:30-17:05  07:30-17:05  07:31-17:05  07:32-17:06
# 06:17-15:32  07:14-16:11  08:06-16:56  08:54-17:46  09:35-18:40  10:10-19:36  10:40-20:33
# 2%           1%           0%           2%           5%           9%           15%
#
# 14           15           16           17           18           19           20
# 07:33-17:06  07:33-17:06  07:34-17:06  07:35-17:07  07:35-17:07  07:36-17:07  07:36-17:08
# 11:06-21:31  11:30-22:28  11:53-23:25  12:16-00:24  12:39-01:25  13:05-02:30  13:36-03:39
# 23%          31%          40%          50%          61%          71%          81%
#
# 21           22           23           24           25           26           27
# 07:37-17:08  07:37-17:09  07:38-17:09  07:38-17:10  07:39-17:11  07:39-17:11  07:39-17:12
# 14:14-04:51  15:02-06:05  16:01-07:15  17:14-08:21  18:30-09:13  19:46-09:54  21:00-10:27
# 89%          96%          99%          100%         97%          91%          83%
#
# 28           29           30           31
# 07:40-17:13  07:40-17:13  07:40-17:14  07:40-17:15
# 22:09-10:56  23:15-11:21  00:18-11:46  01:19-12:10
# 73%          63%          52%          42%
