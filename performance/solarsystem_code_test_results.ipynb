# %%
import solarsystem
print(solarsystem.__version__)
# Out:
# 0.1.8

# %%
# to run the tests pytest will be used
import pytest
print(pytest.__version__)
# Out:
# 8.3.5

# %%
# Test if solarsystem transformation functions are working as expected
# !python ../tests/test_functions.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-8.3.5, pluggy-1.5.0
# rootdir: /home/ouanos/ML/solarsystem
# collected 8 items
#
# ../tests/test_functions.py ........                                      [100%]
#
# ============================== 8 passed in 0.02s ===============================

# %%
# Test if solarsystem calculations are working as expected
# !python ../tests/test_classes.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-8.3.5, pluggy-1.5.0
# rootdir: /home/ouanos/ML/solarsystem
# collected 13 items
#
# ../tests/test_classes.py .............                                   [100%]
#
# ============================== 13 passed in 0.02s ==============================
